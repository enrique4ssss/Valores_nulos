# %%
import pandas as pd

# Cargar el archivo
df = pd.read_csv('Ventas_Totales (1).csv')

# Ver el tipo de dato (dtype) de cada columna
print("--- Tipos de datos ---")
print(df.dtypes)

# Conteo de valores nulos por columna
print("\n--- Conteo de valores nulos ---")
print(df.isnull().sum())
# Out:
# --- Tipos de datos ---
# indice_tiempo                              str
# ventas_precios_corrientes              float64
# ventas_precios_constantes              float64
# ventas_totales_canal_venta             float64
# salon_ventas                           float64
# canales_on_line                        float64
# ventas_totales_medio_pago              float64
# efectivo                               float64
# tarjetas_debito                        float64
# tarjetas_credito                       float64
# otros_medios                           float64
# ventas_totales_grupo_articulos         float64
# subtotal_ventas_alimentos_bebidas      float64
# bebidas                                float64
# almacen                                float64
# panaderia                              float64
# lacteos                                float64
# carnes                                 float64
# verduleria_fruteria                    float64
# ...

# %%
pd.options.display.max_columns = None  # Mostrar todas las filas y columnas

# %%
df.head()
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0    01/01/2017                    27858.9                    27477.3
# 1    01/02/2017                    25994.2                    25223.4
# 2    01/03/2017                    27780.0                    26334.3
# 3    01/04/2017                    29134.3                    27045.9
# 4    01/05/2017                    27969.0                    25631.9
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 27858872.08   27591730.13       267141.956
# 1                 25994200.17   25749179.40       245020.769
# 2                 27780006.52   27472228.72       307777.804
# 3                 29134272.22   28827479.49       306792.733
# 4                 27969004.68   27569311.41       399693.262
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 0                27858872.08  1.023010e+07      6864575.384       9047205.493
# ...

# %%
#Reemplazar los valores nulos de cada columna numérica directamente con su propia media
df = df.fillna(df.mean(numeric_only=True))

#Comprobar que ya no existan valores nulos
print("Conteo total de nulos restantes en el DataFrame:")
print(df.isnull().sum())
# Out:
# Conteo total de nulos restantes en el DataFrame:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %% [markdown]
# Se usa la media para otras porque son valores continuos. Usamos el metodo de fillna con mean.

# %%
#Guardar el archivo limpio en un nuevo CSV
df.to_csv('VentasTotales_Limpio.csv', index=False)
